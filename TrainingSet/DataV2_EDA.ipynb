# %% [markdown]
# **This notebook shows how to access/view training set stored in the database (zarr files).**

# %%
# if zarr not installed run below:
# !pip install zarr
# Out:
# Requirement already satisfied: zarr in /home/idies/miniconda3/lib/python3.6/site-packages (2.3.2)
# Requirement already satisfied: numcodecs>=0.6.2 in /home/idies/miniconda3/lib/python3.6/site-packages (from zarr) (0.6.3)
# Requirement already satisfied: fasteners in /home/idies/miniconda3/lib/python3.6/site-packages (from zarr) (0.15)
# Requirement already satisfied: numpy>=1.7 in /home/idies/miniconda3/lib/python3.6/site-packages (from zarr) (1.17.2)
# Requirement already satisfied: asciitree in /home/idies/miniconda3/lib/python3.6/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: monotonic>=0.1 in /home/idies/miniconda3/lib/python3.6/site-packages (from fasteners->zarr) (1.5)
# Requirement already satisfied: six in /home/idies/miniconda3/lib/python3.6/site-packages (from fasteners->zarr) (1.11.0)

# %%
import pandas as pd
import numpy as np
import zarr
from utilsv2 import *
pd.set_option('display.max_columns', 999)

from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Note:
# We start building the QSO catalog by selecting sources that are in the area of Stripe 82 from the SDSS DR7 Quasar catalog and the [DR14](https://www.sdss.org/dr14/algorithms/qso_catalog/) Quasar catalog seperatly, then find the union of these two samples to form the source catalog, which end up containing ~27k objects. Next, we query the Stripe 82 database on CAS to retrive the PSF magnitudes, errors and from [Stripe 82 DR7 Coadd](https://iopscience.iop.org/article/10.1088/0004-637X/794/2/120) and extinctions in all five bands. The exact query used is shown below:
#
# ```sql
# select q.*, p.objid, p.psfmag_u, p.psfmag_g, p.psfmag_r, p.psfmag_i, p.psfmag_z,
#   p.psfmagerr_u, p.psfmagerr_g, p.psfmagerr_r, p.psfmagerr_i, p.psfmagerr_z, p.extinction_u,
#   p.extinction_g, p.extinction_r, p.extinction_i, p.extinction_z, b.distance
# into mydb.qsoPhoto --ra, dec
# from mydb.s82specqso as q
#   cross apply fgetnearbyobjeq(q.ra, q.dec, 1/60.0) b
#   join photoprimary as p on p.objid = b.objid
# where ((p.flags & 0x10000000) != 0)
#   AND ((p.flags & 0x8100000c00a4) = 0)
#   AND (((p.flags & 0x400000000000) = 0) or (psfmagerr_g<=0.2))
#   AND (((p.flags & 0x100000000000) = 0) or (p.flags & 0x1000) = 0)
#   and (psfmagerr_g <= 1 and psfmagerr_r<= 1 and psfmagerr_i<=1 and psfmagerr_u<= 1 and psfmagerr_z<= 1)
#   and (p.run = 106 or p.run = 206)
# ```
#
# Lastly, we remove the objects don't have reliable detection in the Coadd. We are left with ~25k spectroscopically confirmed AGNs in the final catalog. Later, this catalog is matched to Gaia DR2 for proper motin and parallax measurments and SpIES for MIR detections.
#
# **Missing data**
# All missing data the catalog is marked using `NaN`, except in the id columns (`gaia_id`, `SPIES_ID`, `thing_id`), where an integer '-99' is used.

# %% [markdown]
# #### Check out qso master catalog

# %%
qso_df = get_qso_cat()
qso_df.head(3)
# Out:
#    train_id   ra_sdss  dec_sdss               sdssj         z     z_err  \
# 0         0  310.0377 -1.005592  204009.04-010020.1  2.167268  0.000676
# 1         3  311.6088  0.393812  204626.10+002337.7  0.333015  0.000351
# 2         4  312.3636  0.718380  204927.25+004306.1  1.699121  0.000973
#
#    thing_id           specobjid  spec                objid  psfmag_u  \
# 0       -99  276352159556042752     7  8647475119809364088  19.64425
# 1       -99  537282917827608576     7  8647475121420632840  19.98406
# 2       -99  314071864353751040     7  8647475121957832451  21.65874
#
#    psfmag_g  psfmag_r  psfmag_i  psfmag_z  psfmagerr_u  psfmagerr_g  \
# 0  19.11970  18.69050  18.39786  18.12030     0.008446     0.003265
# 1  18.87617  17.98685  17.88391  17.11791     0.011383     0.001996
# 2  20.98272  20.43363  19.93146  19.81973     0.037532     0.009041
#
#    psfmagerr_r  psfmagerr_i  psfmagerr_z  extinction_u  extinction_g  \
# 0     0.003569     0.002969     0.005960      0.332155      0.244396
# 1     0.001869     0.002298     0.003088      0.494767      0.364045
# 2     0.007869     0.007637     0.022191      0.526905      0.387692
#
#    extinction_r  extinction_i  extinction_z  spec2coadd  ra_sp  dec_sp  \
# 0      0.177257      0.134408      0.095297    0.083856    NaN     NaN
# 1      0.264036      0.200210      0.141952    0.051798    NaN     NaN
# 2      0.281186      0.213215      0.151172    0.154056    NaN     NaN
#
#    SPIES_ID  FLUX_AUTO_ch1  FLUXERR_AUTO_ch1  FLUX_AUTO_ch2  FLUXERR_AUTO_ch2  \
# 0       -99            NaN               NaN            NaN               NaN
# 1       -99            NaN               NaN            NaN               NaN
# 2       -99            NaN               NaN            NaN               NaN
#
#    CLASS_STAR_ch1  CLASS_STAR_ch2  sdss2spies  sdss2gaia              gaia_id  \
# 0             NaN             NaN         NaN   0.024083  4226318531605913088
# 1             NaN             NaN         NaN   0.092993  4228017414511443968
# 2             NaN             NaN         NaN   0.218568  4228378535360381440
#
#    parallax  parallax_error      pmra  pmra_error     pmdec  pmdec_error  lcN  \
# 0  0.225240        0.283972 -0.609215    0.464463 -0.206735     0.305267   60
# 1 -0.149525        0.160723  0.044235    0.275073  0.075344     0.179892   69
# 2 -0.486411        0.729782 -0.776679    2.051325  0.635052     1.033818   54
#
#     psPm[0]   psPm[1]  psParallax    unred_u    unred_g    unred_r    unred_i  \
# 0 -0.609215 -0.206735    0.225240  19.312095  18.875304  18.513243  18.263452
# 1  0.044235  0.075344   -0.149525  19.489293  18.512125  17.722814  17.683700
# 2 -0.776679  0.635052   -0.486411  21.131835  20.595028  20.152444  19.718245
#
#      unred_z  stdColor[0]  stdColor[1]  stdColor[2]  stdColor[3]  \
# 0  18.025003     0.436791     0.362060     0.249792     0.238449
# 1  16.975958     0.977168     0.789311     0.039115     0.707741
# 2  19.668558     0.536807     0.442585     0.434199     0.049687
#
#       psFlux[u]     psFlux[g]      psFlux[r]      psFlux[i]      psFlux[z]
# 0  65942.328054  68419.255122  142798.907734  179737.984132  228014.565848
# 1  56011.332155  58115.957521  295732.889174  306580.434350  599285.639829
# 2  12319.895839  12794.084912   31547.575429   47059.204593   50039.124902

# %% [markdown]
# #### Show column definitions

# %%
qso_cat_meta()
# Out:
# {'CLASS_STAR_ch1': '3.6 micrometer morphology classification, > 0.5 for resolved source',
#  'CLASS_STAR_ch2': '4.5 micrometer morphology classification, > 0.5 for resolved source',
#  'FLUXERR_AUTO_ch1': '3.6 micrometer flux error given by SExtractor',
#  'FLUXERR_AUTO_ch2': '4.5 micrometer flux error given by SExtractor',
#  'FLUX_AUTO_ch1': '3.6 micrometer flux value automatically extracted using SExtractor',
#  'FLUX_AUTO_ch2': '4.5 micrometer flux value automatically extracted using SExtractor',
#  'SPIES_ID': 'Unique ID assigned to each source in SpIES if match exists, otherwise -99',
#  'dec_sdss': 'DEC from SDSS in degrees (J2000 degree)',
#  'dec_sp': 'DEC from SpIES in degrees (J2000)',
#  'extinction_{band}': 'Extinction in u,g,r,i,z',
#  'gaia_id': 'Gaia DR2 source id if match exists, otherwise -99',
#  'lcN': 'Number of data points in the corresponding light curve',
#  'objid': 'DR7 coadd photo object id',
#  'parallax': 'Gaia DR2 parallax in mas',
#  'parallax_error': 'Gaia DR2 parallax error in mas',
#  'pmdec': 'Gaia DR2 proper motion measurement in DEC direction (mas/yr)',
#  'pmdec_error': 'Gaia DR2 proper motion measurement uncertainty in DEC direction (mas/yr)',
#  'pmra': 'Gaia DR2 proper motion measurement in RA direction (mas/yr)',
#  'pmra_error': 'Gaia DR2 proper motion measurement uncertainty in RA direction (mas/yr)',
#  'psFlux[band]': 'LSST nomenclature: point source model flux (nJy), converted from SDSS mag',
#  'psParallax': 'LSST nomenclature: point source model parallax. Same value as parallax',
#  'psPm[0]': 'LSST nomenclature: point source model proper motin in RA. Same value as pmra.',
#  'psPm[1]': 'LSST nomenclature: point source model proper motin in Dec. Same value as pmdec',
#  'psfmag_{band}': 'PSF magnitude in u,g,r,i,z',
#  'psfmagerr_{band}': 'PSF magnitude error in u,g,r,i,z',
#  'ra_sdss': 'RA from SDSS in degrees (J2000 degree)',
#  'ra_sp': 'RA from THE SPITZER IRAC EQUATORIAL SURVEY (SpIES) in degrees (J2000)',
#  'sdss2gaia': 'Distance (in arcsec) between matched source in SDSS and Gaia',
#  'sdss2spies': 'Distance (in arcsec) between matched source in SDSS and SpIES',
#  'sdssj': 'SDSS designation identifier, either DR7 or DR14, depending on the value of column spec',
#  'spec': 'Source of spectra, 7 for SDSS DR7 and 14 for SDSS DR14',
#  'spec2coadd': 'Matching distanct from spectroscopically confirmed QSOs to DR7 coadd (arcsec)',
#  'specobjid': 'SDSS specobjid, refering to the ID of the corresponding spectra of the source',
#  'stdColor[0-4]': 'LSST nomenclature: SDSS color, u-g, g-r, r-i, i-z, from low to high index',
#  'thing_id': 'SDSS thing_id if exists, otherwise -99',
#  'train_id': 'Unique ID for each QSO source in the training set.',
#  'unred_{band}': 'SDSS mag corrected for extinction',
#  'z': 'Spectroscopic redshift',
#  'z_err': 'Error in redshift'}

# %% [markdown]
# #### P.S.
# We added a few more columns to best mimc the LSST data models, specifically **psPm[]**, **psParallax**, **psFlux[]** and **stdColor[]**. Detailed column definition can be obtain using function ``qso_cat_meta()``

# %% [markdown]
# #### Get/Plot light curves
#
# The light curves are also retrived from SDSS CAS using the following query:
#
# ```sql
# select q.train_id, p.run, p.psfmag_u, p.psfmag_g, p.psfmag_r, p.psfmag_i, p.psfmag_z,
#   p.psfmagerr_u, p.psfmagerr_g, p.psfmagerr_r, p.psfmagerr_i, p.psfmagerr_z, p.offsetRa_u,
#   p.offsetRa_g, p.offsetRa_i, p.offsetRa_z, p.offsetDec_u, p.offsetDec_g, p.offsetDec_i,
#   p.offsetDec_z, f.airmass_u, f.airmass_g, f.airmass_r, f.airmass_i, f.airmass_z,
#   LTRIM(STR(mjd_u,20,2)) as mjd_u,
#   LTRIM(STR(mjd_g,20,2)) as mjd_g,
#   LTRIM(STR(mjd_r,20,2)) as mjd_r,
#   LTRIM(STR(mjd_i,20,2)) as mjd_i,
#   LTRIM(STR(mjd_z,20,2)) as mjd_z
# into mydb.s82qsoLC
# from mydb.s82qsoFinal as q -- ra, dec
#   cross apply fgetnearbyobjalleq(q.ra, q.dec, 1/60.0) b
#   join photoobj as p on p.objid = b.objid --photoobj for both primary+secondary
#   join field as f on f.fieldid = p.fieldid
# where ((p.flags & 0x10000000) != 0)
#   AND ((p.flags & 0x8100000c00a4) = 0)
#   AND (((p.flags & 0x400000000000) = 0) or (p.psfmagerr_r <= 0.2))
#   AND (((p.flags & 0x100000000000) = 0) or (p.flags & 0x1000) = 0)
#   and (p.psfmagerr_g <= 1 and p.psfmagerr_r<= 1 and p.psfmagerr_i<=1 and p.psfmagerr_u<= 1 and p.psfmagerr_z<= 1)
#   and (p.run !=106)
#   and (p.run !=206)
#   and f.quality in (2,3)
# order by train_id
# ```
#
# - To retrieve the light curve for any object, use functions ``get_sdss_qso()`` while providing `ID_sdss` as the only input.
# - To plot the light curves, use functions `plot_sdss_qso()` for original data, or use functions `plot_merge_gri()` for merged light curves normalized by mean or median of each band.
#
# To see what arguments can be passed to each function, use the help method, `help(plot_sdss_qso)` for example.

# %%
help(plot_sdss_qso)
# Out:
# Help on function plot_sdss_qso in module utilsv2:
#
# plot_sdss_qso(train_id, bands=['u', 'g', 'r', 'i', 'z'], clip=True)
#     Plot SDSS quasar light curves without merging.
#
#     Args:
#         train_id (int): Unique ID for an object in training sample.
#         bands (list): A list specifying light curves in which bands to plot.
#         clip (bool): Indicates whether to run filter removing outliers.

# %% [markdown]
# **Currently, we only normalize and merge light curve by subtracting the mean or median (can be specified while calling the plot function). Certainly, more sphoiscated light curve merging methods should be implemented, for example, [CREAM](https://academic.oup.com/mnras/article/456/2/1960/1066664), but computing cost should also be considered. For now, this should be okay to get started. Any comments/suggestions for better light curve merging methods are welcome.**

# %%
# plot all data
plot_sdss_qso(0, clip=False, bands=['u']) # original
plot_sdss_qso(0, bands=['u']) # clean

# %% [markdown]
# **Note:**
# From the first plot above, we can see the flux suddenly drop around MJD=53650. We suspect that is caused some kind of calibration failures, since such behavior is observed across many light curves and all occured around that time. Further clean up is needed for a better use of the light curves. So we implemented the feature to remove artifacts by first apply a three point median filter to the light curve, and remove outliers that deviate more than 5-sigma from the median filtered light curve. The filtered light curve is shown in the second plot.

# %%
# an invalid id will raise an Exception
plot_sdss_qso(1)
# Out:
# ExceptionTraceback (most recent call last)
# <ipython-input-6-858c1ae9a759> in <module>
#       1 # an invalid id will raise an Exception
# ----> 2 plot_sdss_qso(1)
#
# ~/workspace/Storage/ywx649999311/AGN_training/Stripe 82/Script_NBs/utilsv2.py in plot_sdss_qso(train_id, bands)
#     204     """
#     205
# --> 206     sdss_lc = get_sdss_qso(train_id)
#     207
#     208     # create fig
#
# ~/workspace/Storage/ywx649999311/AGN_training/Stripe 82/Script_NBs/utilsv2.py in get_sdss_qso(train_id, max_err)
#     101
#     102     if train_id not in qso_id:
# --> 103         raise Exception('train_id provided is not valid!')
#     104
#     105     path = os.path.join(qso_path, 'sdss_lc/{}'.format(train_id))
#
# Exception: train_id provided is not valid!

# %% [markdown]
# A list of valid `train_id`s can found from the master catalog or use the function `valid_ids()`. The returned is a pandas dataframe containing all valid `train_id`s for AGNs and non-AGN variables.

# %%
valid_ids().head(2)
# Out:
#    train_id Type
# 0         0  AGN
# 1         3  AGN

# %%
# merged lc using sdss g, r, i
plot_merge_gri(66)

# %% [markdown]
# ---
# ## Non-AGN variables
#
# ### Note:
# The non-AGN variables catalog consists of all objects in [Ivezic et al. 2007](http://faculty.washington.edu/ivezic/sdss/catalogs/S82variables.html) except those have been identified as AGN using spectrum. Thus we are **NOT** confident that all sources in this catalog are non-AGN. This catalog could contains AGNs that were missed by target selection algorithms at the first place.  All SDSS light curves all also queried directly from CAS using the following query:
#
# ```sql
# select q.train_d, q.ivz_id, p.run, p.psfmag_u, p.psfmag_g, p.psfmag_r, p.psfmag_i, p.psfmag_z,
#   p.psfmagerr_u, p.psfmagerr_g, p.psfmagerr_r, p.psfmagerr_i, p.psfmagerr_z, p.offsetRa_u,
#   p.offsetRa_g, p.offsetRa_i, p.offsetRa_z, p.offsetDec_u, p.offsetDec_g, p.offsetDec_i,
#   p.offsetDec_z, f.airmass_u, f.airmass_g, f.airmass_r, f.airmass_i, f.airmass_z,
#   LTRIM(STR(mjd_u,20,2)) as mjd_u,
#   LTRIM(STR(mjd_g,20,2)) as mjd_g,
#   LTRIM(STR(mjd_r,20,2)) as mjd_r,
#   LTRIM(STR(mjd_i,20,2)) as mjd_i,
#   LTRIM(STR(mjd_z,20,2)) as mjd_z
# into mydb.vstarLC
# from mydb.vstarFinal as q --catalog including ra, dec
#   cross apply fgetnearbyobjalleq(q.ra, q.dec, 1/60.0) b
#   -- join photoobj below to get both primary+secondary object
#   join photoobj as p on p.objid = b.objid
#   join field as f on f.fieldid = p.fieldid
# where ((p.flags & 0x10000000) != 0)
#   AND ((p.flags & 0x8100000c00a4) = 0)
#   AND (((p.flags & 0x400000000000) = 0) or (p.psfmagerr_r <= 0.2))
#   AND (((p.flags & 0x100000000000) = 0) or (p.flags & 0x1000) = 0)
#   and (p.psfmagerr_g <= 1 and p.psfmagerr_r<= 1 and p.psfmagerr_i<=1 and p.psfmagerr_u<= 1 and p.psfmagerr_z<= 1)
#   and (p.run !=106)
#   and (p.run !=206)
#   and f.quality in (2,3)
#   and p.type = 6
# order by train_d
# ```

# %% [markdown]
# #### Check out master catalog

# %%
vstar_df = get_var_cat()
vstar_df.head(2)
# Out:
#    train_id  ivz_id   ra_sdss  dec_sdss  sdss2gaia              gaia_id  \
# 0    100070      74  2.714809  0.963019   0.098278  2546353103253723136
# 1    100073     429  1.145510 -0.887604   0.089019  2545683333166174720
#
#    parallax  parallax_error       pmra  pmra_error      pmdec  pmdec_error  \
# 0 -0.330858        1.105588   0.161619    1.966663  -6.564630     0.950373
# 1  0.982614        0.271784  13.324682    0.567646 -16.236439     0.230887
#
#    ra_sp  dec_sp  SPIES_ID  FLUX_AUTO_ch1  FLUXERR_AUTO_ch1  FLUX_AUTO_ch2  \
# 0    NaN     NaN       -99            NaN               NaN            NaN
# 1    NaN     NaN       -99            NaN               NaN            NaN
#
#    FLUXERR_AUTO_ch2  CLASS_STAR_ch1  CLASS_STAR_ch2  sdss2spies  \
# 0               NaN             NaN             NaN         NaN
# 1               NaN             NaN             NaN         NaN
#
#                  objid  psfmag_u  psfmag_g  psfmag_r  psfmag_i  psfmag_z  \
# 0  8658188596295368704  20.79964  20.04293  19.78893  19.69865  19.61046
# 1  8658170687895109632  21.70556  19.35863  18.00129  17.24292  16.78838
#
#    psfmagerr_u  psfmagerr_g  psfmagerr_r  psfmagerr_i  psfmagerr_z  \
# 0     0.074844     0.030475     0.038231     0.049764     0.074923
# 1     0.161327     0.051916     0.034715     0.013419     0.025616
#
#    extinction_u  extinction_g  extinction_r  extinction_i  extinction_z  lcN  \
# 0      0.123449      0.090832      0.065879      0.049954      0.035418   38
# 1      0.185682      0.136623      0.099091      0.075137      0.053273   14
#
#      psPm[0]    psPm[1]  psParallax    unred_u    unred_g    unred_r  \
# 0   0.161619  -6.564630   -0.330858  20.676191  19.952098  19.723051
# 1  13.324682 -16.236439    0.982614  21.519878  19.222007  17.902199
#
#      unred_i    unred_z  stdColor[0]  stdColor[1]  stdColor[2]  stdColor[3]  \
# 0  19.648696  19.575042     0.724094     0.229047     0.074355     0.073654
# 1  17.167783  16.735107     2.297871     1.319807     0.734417     0.432676
#
#       psFlux[u]     psFlux[g]      psFlux[r]      psFlux[i]      psFlux[z]
# 0  18760.905302  19472.756319   46856.340525   50173.482427   54565.860523
# 1   8603.466401   8943.271578  250694.695652  493074.367005  748131.196335

# %% [markdown]
# #### Show column definitions

# %%
var_cat_meta()
# Out:
# {'CLASS_STAR_ch1': '3.6 micrometer morphology classification, > 0.5 for resolved source',
#  'CLASS_STAR_ch2': '4.5 micrometer morphology classification, > 0.5 for resolved source',
#  'FLUXERR_AUTO_ch1': '3.6 micrometer flux error given by SExtractor',
#  'FLUXERR_AUTO_ch2': '4.5 micrometer flux error given by SExtractor',
#  'FLUX_AUTO_ch1': '3.6 micrometer flux value automatically extracted using SExtractor',
#  'FLUX_AUTO_ch2': '4.5 micrometer flux value automatically extracted using SExtractor',
#  'SPIES_ID': 'Unique ID assigned to each source in SpIES if match exists, otherwise -99',
#  'dec': 'DEC from SDSS in degrees (J2000 degree)',
#  'dec_sp': 'DEC from SpIES in degrees (J2000)',
#  'extinction_{band}': 'Extinction in u,g,r,i,z',
#  'gaia_id': 'Gaia DR2 source id if match exists, otherwise -99',
#  'ivz_id': 'Unique ID for each non-AGN variable source in the training set.',
#  'lcN': 'Number of data points in the corresponding light curve',
#  'objid': 'Photo object (primary) id from Stripe 82 context',
#  'parallax': 'Gaia DR2 parallax in mas',
#  'parallax_error': 'Gaia DR2 parallax error in mas',
#  'pmdec': 'Gaia DR2 proper motion measurement in DEC direction (mas/yr)',
#  'pmdec_error': 'Gaia DR2 proper motion measurement uncertainty in DEC direction (mas/yr)',
#  'pmra': 'Gaia DR2 proper motion measurement in RA direction (mas/yr)',
#  'pmra_error': 'Gaia DR2 proper motion measurement uncertainty in RA direction (mas/yr)',
#  'psFlux[band]': 'LSST nomenclature: point source model flux (nJy), converted from SDSS mag',
#  'psParallax': 'LSST nomenclature: point source model parallax. Same value as parallax',
#  'psPm[0]': 'LSST nomenclature: point source model proper motin in RA. Same value as pmra.',
#  'psPm[1]': 'LSST nomenclature: point source model proper motin in Dec. Same value as pmdec',
#  'psfmag_{band}': 'PSF magnitude in u,g,r,i,z',
#  'psfmagerr_{band}': 'PSF magnitude error in u,g,r,i,z',
#  'ra': 'RA from SDSS in degrees (J2000 degree)',
#  'ra_sp': 'RA from THE SPITZER IRAC EQUATORIAL SURVEY (SpIES) in degrees (J2000)',
#  'sdss2gaia': 'Distance (in arcsec) between matched source in SDSS and Gaia',
#  'sdss2spies': 'Distance (in arcsec) between matched source in SDSS and SpIES',
#  'stdColor[0-4]': 'LSST nomenclature: SDSS color, u-g, g-r, r-i, i-z, from low to high index',
#  'train_id': 'Unique ID for each non-AGN variable source in the training set.',
#  'unred_{band}': 'SDSS mag corrected for extinction'}

# %% [markdown]
# #### P.S.
# We added a few more columns to best mimc the LSST data models, specifically **psPm[]**, **psParallax**, **psFlux[]** and **stdColor[]**. Detailed column definition can be obtain using function ``var_cat_meta()``

# %% [markdown]
# #### Get/Plot light curves
# - To retrieve the light curves, use function `get_sdss_var()` with `train_id` at the input.
# - To plot the light curves, use function `plot_var()` or `plot_merge_gri()`.
#
# The `train_id` for non-AGN variable start at 100070. As for the QSO light curves, `clip` is set to `True` as the default.

# %%
# plot var
plot_var(100070)

# %%
# plot gri merged light curve
plot_merge_gri(100070)
